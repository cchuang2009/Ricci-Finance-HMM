# %% [markdown]
# # Ricci Finance V15-2 Bilingual Lecture / 雙語講義
#
# ## English/Traditional Chinese
# This notebook builds rolling financial networks, compares correlation, Forman-Ricci, and Ollivier-Ricci, identifies HMM regimes, and tests whether a GCN can learn those regimes.
#
# 本講義建立滾動金融網路，比較相關係數、Forman-Ricci 與 Ollivier-Ricci，使用 HMM 辨識市場狀態，並測試 GCN 是否能從圖結構學習這些狀態。

# %% [markdown]
# ## 1. Architecture / 系統架構
#
# ```
# market data → rolling graphs → curvature → graph features → HMM labels → GCN comparison
# ```
#
# **English.** Correlation creates the first-order relationship network. Forman-Ricci is a fast combinatorial curvature. Ollivier-Ricci compares local probability neighborhoods through optimal transport.
#
# **中文。** 相關係數建立第一層關係網路；Forman-Ricci 是快速的組合曲率；Ollivier-Ricci 透過最優傳輸比較兩端點的局部分布。
#
# <img src="network.png" width=80%>
#
# Note
# ---
# 1. Code tested on both jupyter nokebook, and VS code; the snapshot pictures from `app.py` replaced of the original on above: 1  pyecharts/animation not displayed on github, 2. can displayed on VS code.
# 2. Olliver Ricci implemented by scipy not  by GraphRicciCurvature.

# %% [markdown]
# ## 1.1 Relation, Forman-Ricci, and Ollivier-Ricci / 三種方法簡要比較
#
# | Method 方法 | Main question 核心問題 | Strength 優點 | Limitation 限制 |
# |---|---|---|---|
# | Correlation relation 相關網路 | Do two returns move together? 兩檔報酬是否同步？ | Direct, signed, easy to explain 直接、具方向、易解釋 | Pairwise only; no local topology 僅成對，忽略局部拓樸 |
# | Forman-Ricci network | Is an edge supported or overloaded by nearby graph structure? 邊是否受到鄰近結構支撐？ | Very fast; suitable for many rolling frames 計算快，適合大量滾動視窗 | More combinatorial and less transport-aware 較偏組合結構，不直接描述質量搬運 |
# | Ollivier-Ricci network | How similar are the probability neighborhoods around two endpoints? 兩端點局部分布有多相似？ | Rich local geometry; bridge fragility has intuitive meaning 局部幾何豐富，橋接脆弱性直觀 | Slower because optimal transport is solved 計算較慢 |
#
# **Network introductions / 網路簡介**
#
# - **Forman-Ricci network:** the original correlation graph is retained, but every edge receives a Forman curvature derived from edge/node weights and adjacent incidence structure. Negative values often indicate relatively overloaded or bridge-like links.<br><b>Forman-Ricci 網路：</b>保留原相關網路，再依節點、邊權重及鄰接結構計算每條邊的 Forman 曲率；負值常表示相對過載或橋接型連結。
# - **Ollivier-Ricci network:** each endpoint spreads probability mass over itself and neighbors. The Wasserstein transport distance between the two local measures is compared with their graph distance to obtain curvature.<br><b>Ollivier-Ricci 網路：</b>每個端點把機率質量分配至自身及鄰居，再以 Wasserstein 最優傳輸距離比較兩個局部分布，並相對於圖距離得到曲率。
#
# **中文說明：本節使用計算快速的 Forman-Ricci 建立滾動網路，適合先驗證大量時間幀。**

# %% [markdown]
# ## Complete workflow
#
# ```text
# Market data
#    ↓
# Aligned close / volume / returns / dollar volume
#    ↓
# Rolling correlation graphs
#    ↓
# Capital-aware node and edge attributes
#    ↓
# Forman or SciPy-LP Ollivier curvature
#    ↓
# Graph-level feature history
#    ↓
# Gaussian HMM regimes and five-day forecast
#    ↓
# Sector momentum and capital-flow matrix
#    ↓
# Perelman-inspired graph surgery
#    ↓
# Stable 3D Ricci Galaxy
#    ↓
# Pure-PyTorch GCN comparison
#    ↓
# Export tables and reusable dataset
# ```
#
# **中文說明：本節依序說明市場資料、滾動網路、曲率、HMM 與 GCN 的完整處理流程。**

# %%
# %load_ext watermark
# %watermark -m -v -p pandas,yfinance,sklearn,GraphRicciCurvature,scipy,numpy,matplotlib,plotly,pomegranate,hmmlearn,pyecharts
# Out:
# Python implementation: CPython
# Python version       : 3.14.2
# IPython version      : 9.15.0
#
# pandas             : 3.0.5
# yfinance           : 1.5.2
# sklearn            : 1.8.0
# GraphRicciCurvature: 0.5.3.2
# scipy              : 1.18.0
# numpy              : 2.4.6
# matplotlib         : 3.10.8
# plotly             : 6.6.0
# pomegranate        : 1.1.2
# hmmlearn           : 0.3.3
# pyecharts          : 2.1.0
#
# Compiler    : GCC 15.2.1 20251112
# OS          : Linux
# Release     : 6.1.161-1-MANJARO
# Machine     : x86_64
# Processor   :
# CPU cores   : 16
# Architecture: 64bit

# %%
import sys, importlib.util
print("Python", sys.version)
#or forbidden in ["tensorflow", "ot", "GraphRicciCurvature"]:
#   print(forbidden, "installed:", importlib.util.find_spec(forbidden) is not None)
# Out:
# Python 3.14.2 (main, Jan  2 2026, 14:27:39) [GCC 15.2.1 20251112]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import gc

from ricci_finance.data import prepare_market_data
from ricci_finance.pipeline import build_rolling_frames
from ricci_finance.hmm import (
     DEFAULT_HMM_FEATURES, fit_gaussian_hmm, build_regime_labels,
     forecast_hmm_methods,current_run_length,switch_rate
)

from ricci_finance.sectors import (
    assign_sectors,
    sector_momentum,
    sector_flow_matrix,
)

from ricci_finance.surgery import graph_surgery
from ricci_finance.galaxy import stable_galaxy_positions, galaxy_figure

from ricci_finance.gnn import train_gcn_regime

from ricci_finance.echarts_viz import (
    curvature_bar_options, heatmap_options, line_options, loss_options,
    momentum_bar_options, network_options,display_echarts,capital_flow_animation_options
)

from ricci_finance.helper import round_numeric,round_dataframe,round_graph_inplace, \
                                 round_nested,round_plotly_figure,capital_flow_animation_options

# %% [markdown]
# ## 2. Download market data / 下載市場資料
#
# **English.** Add a ticker to `TICKERS`, then add the same ticker and its required sector to `SECTOR_MAP`. The validation cell stops execution when any sector is missing.
#
# **中文。** 同時加入股票與產產業, `TICKS`,`SECTOR_MAP` ；<B>股票缺少產業，驗證儲存格會停止執行</B>

# %%
N_STATES=3
RANDOM_STATE=42
PERIOD = "2y"
INTERVAL = "1d"

WINDOW = 63
STEP = 5
MAX_FRAMES = 80

# Rolling Ricci Curvature
K_NEIGHBORS = 4
MIN_CORR = 0.20
MAX_BRIDGES = 3
MIN_OBS = 25

# HMM
FORECAST_HORIZON = 5

CURVATURE_ENGINE = "ollivier_lp"       # "forman" or "ollivier_lp"
OLLIVIER_ALPHA = 0.50
CAPITAL_ALPHA = 0.35

# animation (ms)
capital_flow_speed = 900

# %%
TICKERS = [
    "NVDA", "AMD", "AVGO", "MRVL", "ANET", "BNT", "CBRS", "LITE",
    "LRCX", "KLAC", "AMAT", "MU", "INTC", "AAPL", "QNT", "QBTS",
    "SPCX", "META", "IONQ",
]

# Required: one sector for every ticker. / 必填：每個 ticker 都要有 sector。
SECTOR_MAP = {
    "NVDA": "Semiconductors", "AMD": "Semiconductors", "AVGO": "Semiconductors",
    "MRVL": "Semiconductors", "ANET": "Networking", "BNT": "QuantumComputing",
    "CBRS": "Semiconductors", "LITE": "Networking", "LRCX": "Equipment",
    "KLAC": "Equipment", "AMAT": "Equipment", "MU": "Memory",
    "INTC": "Semiconductors", "AAPL": "Technology", "QNT": "QuantumComputing",
    "QBTS": "QuantumComputing", "SPCX": "Other", "META": "Internet",
    "IONQ": "QuantumComputing",
}
missing_sectors = [ticker for ticker in TICKERS if not SECTOR_MAP.get(ticker)]
if missing_sectors:
    raise ValueError(f"Missing required sectors / 缺少必要產業: {missing_sectors}")

market = prepare_market_data(tuple(TICKERS), period=PERIOD)
close = market["close"]
returns = market["returns"]
dollar_volume = market["dollar_volume"]
print(f"Loaded {len(close)} rows and {len(close.columns)} tickers")
# Out:
# Loaded 499 rows and 19 tickers

# %% [markdown]
# ## 2.1. Capital concentration
#
# For normalized capital shares $p_i$, the Herfindahl concentration index is
#
# $$H = \sum_i p_i^2.$$
#
# A larger value means capital is concentrated in fewer nodes or edges.
#
# **本節檢查每條邊的相關、距離、權重與 Ricci 曲率；負曲率邊通常較像橋接或脆弱連結。**

# %%
def concentration_index(values) -> float:
    x = np.asarray(list(values), dtype=float)
    x = x[np.isfinite(x)]
    x = np.clip(x, 0.0, None)
    total = float(x.sum())
    if total <= 0:
        return np.nan
    p = x / total
    return round(float(np.sum(p * p)),4)

latest_dv = dollar_volume.iloc[-WINDOW:].mean().dropna()
capital_share = latest_dv / latest_dv.sum()

display(
    pd.DataFrame({
        "mean_dollar_volume": latest_dv,
        "capital_share": capital_share,
    }).sort_values("capital_share", ascending=False)
)
print("Latest-window capital concentration:", concentration_index(latest_dv))
# Out:
#         mean_dollar_volume  capital_share
# Ticker
# MU            4.675935e+10       0.234590
# NVDA          3.247369e+10       0.162919
# SPCX          1.889924e+10       0.094817
# AAPL          1.650205e+10       0.082790
# AMD           1.599485e+10       0.080246
# INTC          1.490755e+10       0.074791
# META          1.102977e+10       0.055336
# AVGO          1.037865e+10       0.052069
# MRVL          1.020340e+10       0.051190
# AMAT          5.068773e+09       0.025430
# LITE          4.870588e+09       0.024436
# LRCX          3.748286e+09       0.018805
# KLAC          2.746708e+09       0.013780
# CBRS          1.782024e+09       0.008940
# ANET          1.529143e+09       0.007672
# IONQ          1.449388e+09       0.007272
# QBTS          7.299508e+08       0.003662
# QNT           2.491637e+08       0.001250
# BNT           1.032589e+06       0.000005
# Latest-window capital concentration: 0.1198

# %%
progress_log = []

def notebook_progress(done, total, date):
    if done == 1 or done == total or done % max(1, total // 5) == 0:
        message = f"{done:>3}/{total:<3}  {pd.Timestamp(date).date()}"
        progress_log.append(message)
        print(message)

# forman/ollivier_lp"

CURVATURE_ENGINE= "ollivier_lp"
frames, feature_df = build_rolling_frames(
    returns=returns,
    dollar_volume=dollar_volume,
    window=WINDOW,
    step=STEP,
    max_frames=MAX_FRAMES,
    k=K_NEIGHBORS,
    min_corr=MIN_CORR,
    max_bridges=MAX_BRIDGES,
    min_obs=MIN_OBS,
    alpha=OLLIVIER_ALPHA,
    curvature_engine=CURVATURE_ENGINE,
    capital_alpha=CAPITAL_ALPHA,
    use_capital=True,
    progress=notebook_progress,
)

print("Frames:", len(frames))
print("Feature rows:", len(feature_df))
display(feature_df.tail(2).T)
# Out:
#   1/80   2024-12-23
#  16/80   2025-04-14
#  32/80   2025-08-08
#  48/80   2025-12-02
#  64/80   2026-03-30
#  80/80   2026-07-24
# Frames: 80
# Feature rows: 80
#                                              78                   79
# date                        2026-07-17 00:00:00  2026-07-24 00:00:00
# nodes                                        18                   19
# edges                                        57                   60
# density                                0.372549             0.350877
# avg_degree                             6.333333             6.315789
# avg_ricci                              0.216705             0.181444
# std_ricci                              0.092489             0.098329
# negative_edge_ratio                         0.0             0.033333
# avg_abs_correlation                    0.546949             0.536211
# components                                    1                    1
# ...

# %%
feature_df[["date", "avg_ricci", "negative_edge_ratio", "curvature_engine"]].tail(2).T
# Out:
#                                       78                   79
# date                 2026-07-17 00:00:00  2026-07-24 00:00:00
# avg_ricci                       0.216705             0.181444
# negative_edge_ratio                  0.0             0.033333
# curvature_engine             ollivier_lp          ollivier_lp

# %% [markdown]
# ## 3. Fast Forman rolling graphs
#
# Use this mode first to validate the full workflow quickly.
#
# **依序說明市場資料、滾動網路、曲率、HMM 與 GCN 的完整處理流程。**

# %%
frames_forman, features_forman = build_rolling_frames(
    returns,
    dollar_volume,
    window=63,
    step=5,
    max_frames=50,
    k=4,
    min_corr=0.2,
    curvature_engine="forman",
)
features_forman.tail(2).T
# Out:
#                                              48                   49
# date                        2026-07-17 00:00:00  2026-07-24 00:00:00
# nodes                                        18                   19
# edges                                        57                   60
# density                                0.372549             0.350877
# avg_degree                             6.333333             6.315789
# avg_ricci                            -10.911615           -10.092487
# std_ricci                              3.404247             2.887061
# negative_edge_ratio                         1.0                  1.0
# avg_abs_correlation                    0.546949             0.536211
# components                                    1                    1
# capital_concentration                  0.132411              0.11919
# edge_capital_concentration             0.035452             0.033304
# edge_stability                         0.774194             0.772727
# ...

# %%
features_forman[["date", "avg_ricci", "negative_edge_ratio", "curvature_engine"]]

# %% [markdown]
# ## 4. SciPy-LP Ollivier-Ricci example
#
# For each edge, SciPy solves the transport plan between the two local probability measures. Begin with few frames because this is slower than Forman.
#
# **本節使用計算快速的 Forman-Ricci 建立滾動網路，適合先驗證大量時間幀。**
#
# **Note:** Use `Scipy-implemented` Ollivier-Ricci$ instead of using `GraphRicciCurvature` packages.

# %%
frames_ollivier, features_ollivier = build_rolling_frames(
    returns,
    dollar_volume,
    window=63,
    step=5,
    max_frames=50,
    k=4,
    min_corr=0.2,
    alpha=0.5,
    curvature_engine="ollivier_lp",
)
features_ollivier[["date", "avg_ricci", "negative_edge_ratio", "curvature_engine"]].tail()
# Out:
#          date  avg_ricci  negative_edge_ratio curvature_engine
# 45 2026-06-25   0.218471             0.000000      ollivier_lp
# 46 2026-07-02   0.217082             0.061224      ollivier_lp
# 47 2026-07-10   0.229974             0.018868      ollivier_lp
# 48 2026-07-17   0.216705             0.000000      ollivier_lp
# 49 2026-07-24   0.181444             0.033333      ollivier_lp

# %%
def validate_hmm_features(
    frame: pd.DataFrame,
    requested: list[str],
) -> list[str]:
    missing = [name for name in requested if name not in frame.columns]
    if missing:
        raise ValueError(f"Missing HMM features: {missing}")

    usable = []
    report = []

    for name in requested:
        finite_count = np.isfinite(
            pd.to_numeric(frame[name], errors="coerce")
        ).sum()
        report.append({
            "feature": name,
            "finite_rows": int(finite_count),
            "total_rows": len(frame),
        })
        if finite_count > 0:
            usable.append(name)

    display(pd.DataFrame(report))
    return usable

HMM_FEATURES = validate_hmm_features(
    feature_df,
    list(DEFAULT_HMM_FEATURES),
)
print("HMM features:", HMM_FEATURES)
# Out:
#                       feature  finite_rows  total_rows
# 0                   avg_ricci           80          80
# 1                   std_ricci           80          80
# 2         negative_edge_ratio           80          80
# 3                     density           80          80
# 4              edge_stability           80          80
# 5       capital_concentration           80          80
# 6  edge_capital_concentration           80          80
# HMM features: ['avg_ricci', 'std_ricci', 'negative_edge_ratio', 'density', 'edge_stability', 'capital_concentration', 'edge_capital_concentration']

# %%
feature_summary = feature_df[HMM_FEATURES].describe().T
feature_summary["latest"] = feature_df[HMM_FEATURES].iloc[-1]
display(feature_summary)
# Out:
#                             count      mean       std       min       25%  \
# avg_ricci                    80.0  0.220269  0.019794  0.169355  0.213960
# std_ricci                    80.0  0.111831  0.024903  0.068077  0.095171
# negative_edge_ratio          80.0  0.034935  0.043465  0.000000  0.000000
# density                      80.0  0.389643  0.024535  0.325000  0.375000
# edge_stability               80.0  0.768183  0.086005  0.557377  0.723659
# capital_concentration        80.0  0.192724  0.038994  0.119190  0.159017
# edge_capital_concentration   80.0  0.048270  0.009595  0.033092  0.040495
#
#                                  50%       75%       max    latest
# avg_ricci                   0.224032  0.233354  0.254863  0.181444
# std_ricci                   0.105724  0.125405  0.189777  0.098329
# negative_edge_ratio         0.020842  0.062585  0.177778  0.033333
# density                     0.391667  0.408333  0.433333  0.350877
# ...

# %%
from IPython.display import HTML

try:
    from pyecharts.charts import Line
    from pyecharts import options as opts
    from pyecharts.globals import CurrentConfig, NotebookType

    CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK

    line = Line(init_opts=opts.InitOpts(width="100%", height="460px"))
    dates = pd.to_datetime(feature_df["date"]).dt.strftime("%Y-%m-%d").tolist()
    line.add_xaxis(dates)

    for column in [
        "avg_ricci",
        "negative_edge_ratio",
        "edge_stability",
        "capital_concentration",
        "edge_capital_concentration",
    ]:
        if column in feature_df:
            values = (
                pd.to_numeric(feature_df[column], errors="coerce")
                .round(6)
                .where(lambda s: s.notna(), None)
                .tolist()
            )
            line.add_yaxis(
                column,
                values,
                is_symbol_show=False,
                label_opts=opts.LabelOpts(is_show=False),
            )

    line.set_global_opts(
        title_opts=opts.TitleOpts(title="Rolling Ricci and capital features"),
        tooltip_opts=opts.TooltipOpts(trigger="axis"),
        datazoom_opts=[
            opts.DataZoomOpts(type_="inside"),
            opts.DataZoomOpts(type_="slider"),
        ],
        legend_opts=opts.LegendOpts(type_="scroll"),
    )
    #line.render_notebook()
    fn_line="line.html"
    line.render(fn_line)
    display(HTML(fn_line))
    
except ImportError:
    print("Install pyecharts to display the interactive feature chart:")
    print("python -m pip install 'pyecharts>=2,<3'")

# %%
display(HTML(fn_line))

# %% [markdown]
# <img src="line.png">

# %% [markdown]
# ## 5. Inspect edge curvature
#
# **中文說明：本節檢查每條邊的相關、距離、權重與 Ricci 曲率；負曲率邊通常較像橋接或脆弱連結。**

# %%
#latest = frames_ollivier[-1]["graph"]
latest_frame = frames[-1]
latest_graph = latest_frame["graph"]
latest_date = pd.Timestamp(latest_frame["date"])

edge_table = pd.DataFrame([
    {
        "source": str(u),
        "target": str(v),
        "correlation": d.get("correlation"),
        "distance": d.get("distance"),
        "weight": d.get("weight"),
        "ricciCurvature": d.get("ricciCurvature"),
        "wassersteinDistance": d.get("wassersteinDistance"),
        "edge_capital_flow": d.get("edge_capital_flow"),
        "engine": d.get(
            "ricci_engine",
            latest_graph.graph.get("curvature_engine"),
        ),
    }
    for u, v, d in latest_graph.edges(data=True)
]).sort_values("ricciCurvature")

print("Latest frame:", latest_date.date())
print("Nodes:", latest_graph.number_of_nodes())
print("Edges:", latest_graph.number_of_edges())
display(edge_table)
# Out:
# Latest frame: 2026-07-24
# Nodes: 19
# Edges: 60
#    source target  correlation  distance    weight  ricciCurvature  \
# 52   META   NVDA     0.294334  1.187995  1.176465       -0.028038
# 59   QBTS   SPCX     0.392801  1.101997  1.099171       -0.027242
# 55   MRVL   QBTS     0.482077  1.017765  1.015432        0.016973
# 29   CBRS   LITE     0.376498  1.116693  1.114516        0.034303
# 48   LITE   QBTS     0.491506  1.008458  1.006828        0.035814
# 39   IONQ   LRCX     0.588718  0.906953  0.904785        0.037868
# 38   IONQ   QBTS     0.858300  0.532353  0.531536        0.045238
# 14    AMD    BNT     0.285682  1.195255  1.195178        0.053438
# 27    BNT   QBTS     0.263129  1.213978  1.213963        0.072818
# 30   CBRS   INTC     0.356142  1.134775  1.131104        0.077554
# 15    AMD   IONQ     0.582630  0.913641  0.909153        0.084820
# 17    AMD    QNT     0.536721  0.962579  0.960748        0.113161
# ...

# %% [markdown]
# ### 6.1. Node-level capital and curvature table
#
# **中文說明：本節檢查每條邊的相關、距離、權重與 Ricci 曲率；負曲率邊通常較像橋接或脆弱連結。**

# %%
node_rows = []
for node, attrs in latest_graph.nodes(data=True):
    incident_curvature = [
        float(latest_graph.edges[node, nbr].get("ricciCurvature", np.nan))
        for nbr in latest_graph.neighbors(node)
    ]
    node_rows.append({
        "ticker": str(node),
        "sector": assign_sectors([node])[str(node)],
        "degree": latest_graph.degree(node),
        "capital_share": attrs.get("capital_share"),
        "mean_incident_ricci": np.nanmean(incident_curvature)
            if incident_curvature else np.nan,
    })

node_table = pd.DataFrame(node_rows).sort_values(
    ["capital_share", "degree"],
    ascending=False,
)
display(node_table)
# Out:
#    ticker            sector  degree  capital_share  mean_incident_ricci
# 14     MU            Memory       8       0.231860             0.268453
# 15   NVDA    Semiconductors       6       0.163523             0.116921
# 18   SPCX             Other       5       0.096521             0.166777
# 0    AAPL        Technology       4       0.082126             0.209434
# 2     AMD    Semiconductors       9       0.080990             0.151262
# 7    INTC    Semiconductors       6       0.075426             0.180371
# 12   META          Internet       3       0.055344             0.108080
# 4    AVGO    Semiconductors       5       0.052170             0.268102
# 13   MRVL    Semiconductors      10       0.051188             0.208874
# 1    AMAT         Equipment       7       0.025221             0.196383
# 10   LITE        Networking       7       0.024439             0.195155
# 11   LRCX         Equipment      10       0.018678             0.214590
# ...

# %% [markdown]
# ### 6.2. Node-level capital and curvature table
#
# **中文說明：本節檢查每條邊的相關、距離、權重與 Ricci 曲率；負曲率邊通常較像橋接或脆弱連結。**

# %%
node_rows = []
for node, attrs in latest_graph.nodes(data=True):
    incident_curvature = [
        float(latest_graph.edges[node, nbr].get("ricciCurvature", np.nan))
        for nbr in latest_graph.neighbors(node)
    ]
    node_rows.append({
        "ticker": str(node),
        "sector": assign_sectors([node])[str(node)],
        "degree": latest_graph.degree(node),
        "capital_share": attrs.get("capital_share"),
        "mean_incident_ricci": np.nanmean(incident_curvature)
            if incident_curvature else np.nan,
    })

node_table = pd.DataFrame(node_rows).sort_values(
    ["capital_share", "degree"],
    ascending=False,
)
display(node_table)
# Out:
#    ticker            sector  degree  capital_share  mean_incident_ricci
# 14     MU            Memory       8       0.231860             0.268453
# 15   NVDA    Semiconductors       6       0.163523             0.116921
# 18   SPCX             Other       5       0.096521             0.166777
# 0    AAPL        Technology       4       0.082126             0.209434
# 2     AMD    Semiconductors       9       0.080990             0.151262
# 7    INTC    Semiconductors       6       0.075426             0.180371
# 12   META          Internet       3       0.055344             0.108080
# 4    AVGO    Semiconductors       5       0.052170             0.268102
# 13   MRVL    Semiconductors      10       0.051188             0.208874
# 1    AMAT         Equipment       7       0.025221             0.196383
# 10   LITE        Networking       7       0.024439             0.195155
# 11   LRCX         Equipment      10       0.018678             0.214590
# ...

# %% [markdown]
# ## 6. Fit HMM regimes
#
# `GaussianHMM` uses separate `fit()` and `predict()` calls inside the package. It does not call `fit_predict()`.
#
# **中文說明：本節以 Gaussian HMM 將滾動圖特徵壓縮為市場狀態，並檢查狀態機率、轉移與預測。**

# %%
# features_ollivier/  features_forman

 
if  len(features_ollivier)<max(12,N_STATES*4): 
    features_Ricci = features_forman.copy()
    frames_Ricci = frames_forman.copy()
    print("Use Forman Ricci.")  
else:
    features_Ricci =  features_ollivier.copy()
    frames_Ricci = frames_ollivier.copy() 
    print("use Ollivier Ricci.")


hmm = fit_gaussian_hmm(
    features_Ricci ,
    list(DEFAULT_HMM_FEATURES),
    n_states=N_STATES,
    random_state=42,
)
aligned_frames = [frames_Ricci[i] for i in hmm.valid_index]
aligned_features = features_Ricci.iloc[hmm.valid_index].reset_index(drop=True).copy()
aligned_features["hmm_state"] = hmm.states
regime_names = build_regime_labels(aligned_features, hmm.states)
aligned_features["regime_name"] = [regime_names[int(s)] for s in hmm.states]
aligned_features.tail(2).T
# Out:
# use Ollivier Ricci.
#                                              48                   49
# date                        2026-07-17 00:00:00  2026-07-24 00:00:00
# nodes                                        18                   19
# edges                                        57                   60
# density                                0.372549             0.350877
# avg_degree                             6.333333             6.315789
# avg_ricci                              0.216705             0.181444
# std_ricci                              0.092489             0.098329
# negative_edge_ratio                         0.0             0.033333
# avg_abs_correlation                    0.546949             0.536211
# components                                    1                    1
# capital_concentration                  0.132411              0.11919
# edge_capital_concentration             0.035452             0.033304
# ...

# %%
gc.collect()

hmm_result = fit_gaussian_hmm(
    feature_df=feature_df,
    features=HMM_FEATURES,
    n_states=N_STATES,
    random_state=RANDOM_STATE,
)

valid_feature_df = feature_df.iloc[hmm_result.valid_index].copy()
valid_feature_df["hmm_state"] = hmm_result.states

regime_names = build_regime_labels(
    valid_feature_df,
    hmm_result.states,
)
valid_feature_df["regime_name"] = [
    regime_names[int(state)]
    for state in hmm_result.states
]

print("Valid HMM rows:", len(valid_feature_df))
print("Regime names:", regime_names)
display(valid_feature_df.tail(2).T)
# Out:
# Valid HMM rows: 80
# Regime names: {0: 'Stress', 1: 'Transition', 2: 'Normal'}
#                                              78                   79
# date                        2026-07-17 00:00:00  2026-07-24 00:00:00
# nodes                                        18                   19
# edges                                        57                   60
# density                                0.372549             0.350877
# avg_degree                             6.333333             6.315789
# avg_ricci                              0.216705             0.181444
# std_ricci                              0.092489             0.098329
# negative_edge_ratio                         0.0             0.033333
# avg_abs_correlation                    0.546949             0.536211
# components                                    1                    1
# capital_concentration                  0.132411              0.11919
# ...

# %% [markdown]
# ### 6.3 Regime statistics and transition matrix
#
# **中文說明：本節以 Gaussian HMM 將滾動圖特徵壓縮為市場狀態，並檢查狀態機率、轉移與預測。**

# %%
regime_stats = (
    valid_feature_df
    .groupby(["hmm_state", "regime_name"])[HMM_FEATURES]
    .agg(["mean", "std", "min", "max"])
)
display(regime_stats)

transition = pd.DataFrame(
    hmm_result.model.transmat_,
    index=[regime_names[i] for i in range(N_STATES)],
    columns=[regime_names[i] for i in range(N_STATES)],
)
display(transition)
# Out:
#                       avg_ricci                               std_ricci  \
#                            mean       std       min       max      mean
# hmm_state regime_name
# 0         Stress       0.208979  0.027099  0.169355  0.254863  0.137660
# 1         Transition   0.215525  0.012383  0.181444  0.236865  0.107950
# 2         Normal       0.230794  0.008071  0.210933  0.246494  0.095117
#
#                                                     negative_edge_ratio  \
#                             std       min       max                mean
# hmm_state regime_name
# 0         Stress       0.022000  0.103696  0.189777            0.083508
# 1         Transition   0.015277  0.083227  0.149143            0.030155
# 2         Normal       0.012249  0.068077  0.124931            0.002245
#
#                                  ... edge_stability            \
#                             std  ...            min       max
# hmm_state regime_name            ...
# ...

# %% [markdown]
# ### 6.5. HMM regime timeline
#
# **中文說明：本節以 Gaussian HMM 將滾動圖特徵壓縮為市場狀態，並檢查狀態機率、轉移與預測。**

# %%
try:
    from pyecharts.charts import Line
    from pyecharts import options as opts

    timeline = (
        Line(init_opts=opts.InitOpts(width="100%", height="400px"))
        .add_xaxis(
            pd.to_datetime(valid_feature_df["date"])
            .dt.strftime("%Y-%m-%d")
            .tolist()
        )
        .add_yaxis(
            "HMM state",
            valid_feature_df["hmm_state"].astype(int).tolist(),
            is_step=True,
            is_symbol_show=False,
            label_opts=opts.LabelOpts(is_show=False),
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title="HMM regime timeline"),
            tooltip_opts=opts.TooltipOpts(trigger="axis"),
            datazoom_opts=[
                opts.DataZoomOpts(type_="inside"),
                opts.DataZoomOpts(type_="slider"),
            ],
            yaxis_opts=opts.AxisOpts(
                min_=0,
                max_=N_STATES - 1,
                interval=1,
            ),
        )
    )
    #timeline.render_notebook()
    timeline.render("timeline.html")
    display(HTML("timeline.html"))
except ImportError:
    display(valid_feature_df[["date", "hmm_state", "regime_name"]].tail(30))

# %% [markdown]
# <img src="timeline.png">

# %% [markdown]
# ###  6.6. Five-trading-day regime forecast
#
# **中文說明：本節以 Gaussian HMM 將滾動圖特徵壓縮為市場狀態，並檢查狀態機率、轉移與預測。**

# %%
current_state = int(hmm_result.states[-1])
current_name = regime_names[current_state]

forecast_df = forecast_hmm_methods(
    hmm_result.model,
    posterior_last=np.asarray(hmm_result.posterior[-1], dtype=float),
    viterbi_last=current_state,
    horizon=FORECAST_HORIZON,
    n_sim=5000,
    random_state=RANDOM_STATE,
    current_run_length=current_run_length(hmm_result.states),
)

forecast_df["regime_name"] = forecast_df["state"].map(regime_names)

print("Current regime:", current_state, current_name)
print("Current run length:", current_run_length(hmm_result.states))
print("Historical switch rate:", switch_rate(hmm_result.states))
display(forecast_df)
# Out:
# Current regime: 1 Transition
# Current run length: 5
# Historical switch rate: 0.189873417721519
#    day  state  probability                 method regime_name
# 0    1      1     0.664626  posterior propagation  Transition
# 1    2      1     0.484836  posterior propagation  Transition
# 2    3      2     0.403729  posterior propagation      Normal
# 3    4      2     0.436392  posterior propagation      Normal
# 4    5      2     0.453272  posterior propagation      Normal

# %% [markdown]
# ### 6.7 Five-trading-day regime forecast
# #### Sector momentum and capital-flow matrix
#
# **中文說明：本節以 Gaussian HMM 將滾動圖特徵壓縮為市場狀態，並檢查狀態機率、轉移與預測。**

# %%
sector_map = assign_sectors(latest_graph.nodes())

momentum = sector_momentum(
    close,
    sector_map,
    latest_date=latest_date,
    lookback=5,
)

flow = sector_flow_matrix(
    latest_graph,
    sector_map,
    momentum=momentum,
)

sectors = flow.index.tolist()

display(momentum.rename("five_day_momentum").to_frame())
display(flow)
# Out:
#                   five_day_momentum
# sector
# Memory                     0.084811
# Semiconductors             0.042552
# Networking                 0.036539
# Technology                -0.002157
# Equipment                 -0.007954
# QuantumComputing          -0.044702
# Other                     -0.071941
# Internet                  -0.078668
#                   Equipment  Internet    Memory  Networking     Other  \
# Equipment          0.103037  0.000000  0.151817    0.030935  0.000000
# Internet           0.000000  0.000000  0.000000    0.000000  0.016782
# Memory             0.151817  0.000000  0.000000    0.042351  0.000000
# Networking         0.030935  0.000000  0.042351    0.012955  0.000000
# Other              0.000000  0.016782  0.000000    0.000000  0.000000
# QuantumComputing   0.006845  0.000000  0.000000    0.004626  0.007556
# Semiconductors     0.269420  0.032702  0.305723    0.048307  0.007205
# ...

# %%
import json
import uuid
from IPython.display import HTML, display

def display_echarts(options, width="100%", height="430px"):
    div_id = f"echarts_{uuid.uuid4().hex}"

    html = f"""
    <script src="https://cdn.jsdelivr.net/npm/echarts/dist/echarts.min.js"></script>

    <div id="{div_id}" style="width:{width};height:{height};"></div>

    <script>
    var chart = echarts.init(document.getElementById("{div_id}"));
    chart.setOption({json.dumps(options)});
    </script>
    """

    display(HTML(html))


if momentum is not None and len(momentum) > 0:
    momentum_options = round_nested(
        momentum_bar_options(momentum),
        digits=4,
    )

    display_echarts(
        momentum_options,
        height="430px",
    )
else:
    print("No momentum data available.")
# Out:
#     <script src="https://cdn.jsdelivr.net/npm/echarts/dist/echarts.min.js"></script>
#
#     <div id="echarts_94d57ea41b844a47acc809ede72d2e2b" style="width:100%;height:430px;"></div>
#
#     <script>
#     var chart = echarts.init(document.getElementById("echarts_94d57ea41b844a47acc809ede72d2e2b"));
#     chart.setOption({"backgroundColor": "#FBFCFE", "title": {"text": "Sector momentum", "left": 10}, "tooltip": {"trigger": "axis", "axisPointer": {"type": "shadow"}}, "grid": {"left": 35, "right": 20, "top": 55, "bottom": 25, "containLabel": true}, "xAxis": {"type": "value", "name": "5-day return"}, "yAxis": {"type": "category", "data": ["Internet", "Other", "QuantumComputing", "Equipment", "Technology", "Networking", "Semiconductors", "Memory"]}, "series": [{"type": "bar", "data": [-0.0787, -0.0719, -0.0447, -0.008, -0.0022, 0.0365, 0.0426, 0.0848]}]});
#     </script>

# %%
# Display sector capital-flow heatmap
if flow is not None and not flow.empty:
    display_echarts(
        round_nested(
            heatmap_options(
                flow,
                "Sector capital-flow matrix",
            ),
            digits=4,
        ),
        height="440px",
    )
else:
    print("No capital-flow data available.")
# Out:
#     <script src="https://cdn.jsdelivr.net/npm/echarts/dist/echarts.min.js"></script>
#
#     <div id="echarts_bb3d06a51ab14794b42f4fbffcedf76b" style="width:100%;height:440px;"></div>
#
#     <script>
#     var chart = echarts.init(document.getElementById("echarts_bb3d06a51ab14794b42f4fbffcedf76b"));
# ...

# %% [markdown]
# <img src="momentum.png" width=28%><img src="heatmap.png" width=50%>

# %%
sector_map = dict(zip(close.columns, sectors))

print(sector_map)
# Out:
# {'AAPL': 'Equipment', 'AMAT': 'Internet', 'AMD': 'Memory', 'ANET': 'Networking', 'AVGO': 'Other', 'BNT': 'QuantumComputing', 'CBRS': 'Semiconductors', 'INTC': 'Technology'}

# %% [markdown]
# ### Ticker with Sector
#
# **中文說明：本節展示產業動能與模型化資金流分數；此分數無量綱，並非美元金額。**

# %%
sector_map = {ticker: SECTOR_MAP[ticker] for ticker in close.columns}
sector_table = (
    pd.Series(sector_map, name="sector")
    .rename_axis("ticker")
    .reset_index()
    .sort_values(["sector", "ticker"])
    .reset_index(drop=True)
)
display(sector_table)
# Out:
#    ticker            sector
# 0    AMAT         Equipment
# 1    KLAC         Equipment
# 2    LRCX         Equipment
# 3    META          Internet
# 4      MU            Memory
# 5    ANET        Networking
# 6    LITE        Networking
# 7    SPCX             Other
# 8     BNT  QuantumComputing
# 9    IONQ  QuantumComputing
# 10   QBTS  QuantumComputing
# 11    QNT  QuantumComputing
# 12    AMD    Semiconductors
# 13   AVGO    Semiconductors
# 14   CBRS    Semiconductors
# 15   INTC    Semiconductors
# 16   MRVL    Semiconductors
# 17   NVDA    Semiconductors
# 18   AAPL        Technology

# %%
# sectors = sorted(set(sector_map.values()))
# Out:
# ['Equipment', 'Internet', 'Memory', 'Networking', 'Other', 'Semiconductors', 'Technology']

# %%
from collections.abc import Mapping


momentum = sector_momentum(
    close,
    sector_map,
    latest_date=latest_date,
)

# %%
sector_table = (
    pd.Series(sector_map, name="sector")
    .rename_axis("ticker")
    .reset_index()
    .sort_values(["sector", "ticker"])
    .reset_index(drop=True)
)

display(sector_table)
# Out:
#    ticker            sector
# 0    AMAT         Equipment
# 1    KLAC         Equipment
# 2    LRCX         Equipment
# 3    META          Internet
# 4      MU            Memory
# 5    ANET        Networking
# 6    LITE        Networking
# 7    SPCX             Other
# 8     BNT  QuantumComputing
# 9    IONQ  QuantumComputing
# 10   QBTS  QuantumComputing
# 11    QNT  QuantumComputing
# 12    AMD    Semiconductors
# 13   AVGO    Semiconductors
# 14   CBRS    Semiconductors
# 15   INTC    Semiconductors
# 16   MRVL    Semiconductors
# 17   NVDA    Semiconductors
# 18   AAPL        Technology

# %%
ROUND_DIGITS =4
flow_animation = capital_flow_animation_options(
    aligned_frames,
    close,
    sector_map,
    interval_ms=capital_flow_speed,
)

# %%
display_echarts(
    round_nested(flow_animation, digits=4),
    height="760px",
)
# Out:
#     <script src="https://cdn.jsdelivr.net/npm/echarts/dist/echarts.min.js"></script>
#
#     <div id="echarts_3c97e845e2c549fea685e7b2b4211d13" style="width:100%;height:760px;"></div>
#
#     <script>
#     var chart = echarts.init(document.getElementById("echarts_3c97e845e2c549fea685e7b2b4211d13"));
# ...

# %% [markdown]
# <img src="animation.png">

# %% [markdown]
# ##  7. Perelman-inspired graph surgery
#
# This is a financial-network heuristic, not Perelman's differential-geometric surgery. It removes sufficiently negative-curvature edges and then compares topology before and after removal.
#
# **中文說明：本節將圖手術視為壓力測試，用來觀察移除脆弱邊後的結構變化，而非真實市場切斷預測。**

# %%
negative_curvatures = edge_table["ricciCurvature"].dropna()
if len(negative_curvatures):
    surgery_threshold = float(negative_curvatures.quantile(0.20))
else:
    surgery_threshold = -1.0

surgery_graph, surgery_info = graph_surgery(
    latest_graph,
    curvature_threshold=surgery_threshold,
    min_component_size=2,
)

surgery_summary = pd.DataFrame([{
    "threshold": surgery_threshold,
    "nodes_before": latest_graph.number_of_nodes(),
    "edges_before": latest_graph.number_of_edges(),
    "components_before": nx.number_connected_components(latest_graph),
    "nodes_after": surgery_graph.number_of_nodes(),
    "edges_after": surgery_graph.number_of_edges(),
    "components_after": nx.number_connected_components(surgery_graph),
    "removed_edges": len(surgery_info.get("removed_edges", [])),
}])

display(surgery_summary)
display(pd.DataFrame(
    surgery_info.get("removed_edges", []),
    columns=["source", "target"],
))
# Out:
#    threshold  nodes_before  edges_before  components_before  nodes_after  \
# 0   0.115059            19            60                  1           19
#
#    edges_after  components_after  removed_edges
# 0           48                 1             12
#    source target
# 0     AMD    BNT
# 1     AMD   IONQ
# 2     AMD    QNT
# 3     BNT   QBTS
# 4    CBRS   LITE
# 5    CBRS   INTC
# 6    IONQ   QBTS
# 7    IONQ   LRCX
# 8    LITE   QBTS
# 9    META   NVDA
# 10   MRVL   QBTS
# 11   QBTS   SPCX

# %% [markdown]
# <img src="surgery-1.png" width=40%> <img src="surgery-2.png" width=40%>

# %% [markdown]
# ## 8. Stable Plotly 3D Ricci Galaxy — unchanged
#
# The Galaxy design is intentionally kept unchanged:
#
# - sector → orbital direction
# - capital share → radius
# - node Ricci curvature → height
#
# **中文說明：本節展示產業動能與模型化資金流分數；此分數無量綱，並非美元金額。**

# %%
combined_graph = nx.compose_all([
    frame["graph"]
    for frame in frames
])

all_sectors = assign_sectors(
    [str(node) for node in combined_graph.nodes]
)

positions_3d = stable_galaxy_positions(
    combined_graph,
    all_sectors,
)

galaxy = galaxy_figure(
    latest_graph,
    all_sectors,
    title="Latest capital-flow galaxy",
)
galaxy.show()

# %% [markdown]
# ## 9. Train the pure-PyTorch GCN
#
# The GNN receives graphs, HMM labels, and a ticker-to-sector dictionary. The graph and label lengths are guaranteed equal by `valid_index`.
#
# **中文說明：本節以 Gaussian HMM 將滾動圖特徵壓縮為市場狀態，並檢查狀態機率、轉移與預測。**

# %%
aligned_frames = [
    frames[int(index)]
    for index in hmm_result.valid_index
]

aligned_graphs = [
    frame["graph"]
    for frame in aligned_frames
]

assert len(aligned_graphs) == len(hmm_result.states)

print("Aligned graphs:", len(aligned_graphs))
print("Aligned labels:", len(hmm_result.states))
print("First aligned date:", aligned_frames[0]["date"])
print("Last aligned date:", aligned_frames[-1]["date"])
# Out:
# Aligned graphs: 80
# Aligned labels: 80
# First aligned date: 2024-12-23 00:00:00
# Last aligned date: 2026-07-24 00:00:00

# %%
import inspect

all_nodes = list(latest_graph.nodes())
gnn_signature = inspect.signature(train_gcn_regime)
print("train_gcn_regime signature:")
print(gnn_signature)

gnn_kwargs = {
    "epochs": 150,
    "hidden_dim": 32,
    "learning_rate": 0.01,
    "weight_decay": 1e-4,
    "random_state": RANDOM_STATE,
}

# Keep compatibility if a package revision uses a narrower signature.
accepted = set(gnn_signature.parameters)
gnn_kwargs = {
    key: value
    for key, value in gnn_kwargs.items()
    if key in accepted
}

gnn_result = train_gcn_regime(
    aligned_graphs,
    hmm_result.states,
    assign_sectors(all_nodes),
    **gnn_kwargs,
)

print("GNN training complete")
print("Test accuracy:", getattr(gnn_result, "accuracy", np.nan))
print("Balanced accuracy:", getattr(gnn_result, "balanced_accuracy", np.nan))
print("Majority baseline:", getattr(gnn_result, "majority_baseline", np.nan))
print("Device:", getattr(gnn_result, "device", "unknown"))
# Out:
# train_gcn_regime signature:
# (graphs: 'Sequence[nx.Graph]', labels: 'Sequence[int]', sectors: 'Dict[str, str]', epochs: 'int' = 120, hidden: 'int' = 24, random_state: 'int' = 42) -> 'GNNResult'
# GNN training complete
# Test accuracy: 0.7916666666666666
# Balanced accuracy: 0.5641025641025641
# Majority baseline: nan
# Device: cuda

# %% [markdown]
# ### Train the pure-PyTorch GCN
# The package uses ordinary PyTorch tensors. It does not require PyTorch Geometric, torch_scatter, or torch_sparse.
#
# **中文說明：本節訓練純 PyTorch GCN，測試網路拓樸是否足以重建 HMM 狀態標籤。**

# %%
gnn_signature = inspect.signature(train_gcn_regime)
print("train_gcn_regime signature:")
print(gnn_signature)

gnn_kwargs = {
    "epochs": 150,
    "hidden_dim": 32,
    "learning_rate": 0.01,
    "weight_decay": 1e-4,
    "random_state": RANDOM_STATE,
}

# Keep compatibility if a package revision uses a narrower signature.
accepted = set(gnn_signature.parameters)
gnn_kwargs = {
    key: value
    for key, value in gnn_kwargs.items()
    if key in accepted
}

gnn_result = train_gcn_regime(
    aligned_graphs,
    hmm_result.states,
    assign_sectors(all_nodes),
    **gnn_kwargs,
)

print("GNN training complete")
print("Test accuracy:", getattr(gnn_result, "accuracy", np.nan))
print("Balanced accuracy:", getattr(gnn_result, "balanced_accuracy", np.nan))
print("Majority baseline:", getattr(gnn_result, "majority_baseline", np.nan))
print("Device:", getattr(gnn_result, "device", "unknown"))
# Out:
# train_gcn_regime signature:
# (graphs: 'Sequence[nx.Graph]', labels: 'Sequence[int]', sectors: 'Dict[str, str]', epochs: 'int' = 120, hidden: 'int' = 24, random_state: 'int' = 42) -> 'GNNResult'
# GNN training complete
# Test accuracy: 0.7916666666666666
# Balanced accuracy: 0.5641025641025641
# Majority baseline: nan
# Device: cuda

# %% [markdown]
# #### GNN prediction comparison
#
# **中文說明：本節訓練純 PyTorch GCN，測試網路拓樸是否足以重建 HMM 狀態標籤。**

# %%
test_indices = np.asarray(
    getattr(gnn_result, "test_indices", []),
    dtype=int,
)
predictions_ = np.asarray(
    getattr(gnn_result, "predictions", []),
    dtype=int,
)
predictions=predictions_[test_indices]

labels = np.asarray(
    getattr(gnn_result, "labels", hmm_result.states),
    dtype=int,
)

#labels=labels_[test_indices]

comparison = pd.DataFrame()

if len(test_indices) and len(predictions):
    comparison = pd.DataFrame({
        "date": [
            aligned_frames[int(i)]["date"]
            for i in test_indices
        ],
        "HMM_state": labels[test_indices],
        "GCN_prediction": predictions,
    })
    comparison["HMM_regime"] = comparison["HMM_state"].map(regime_names)
    comparison["GCN_regime"] = comparison["GCN_prediction"].map(regime_names)
    comparison["correct"] = (
        comparison["HMM_state"] == comparison["GCN_prediction"]
    )

display(comparison)
# Out:
#          date  HMM_state  GCN_prediction  HMM_regime  GCN_regime  correct
# 0  2026-02-06          2               2      Normal      Normal     True
# 1  2026-02-13          1               1  Transition  Transition     True
# 2  2026-02-23          1               1  Transition  Transition     True
# 3  2026-03-02          1               1  Transition  Transition     True
# 4  2026-03-09          2               2      Normal      Normal     True
# 5  2026-03-16          2               2      Normal      Normal     True
# 6  2026-03-23          2               2      Normal      Normal     True
# 7  2026-03-30          2               2      Normal      Normal     True
# 8  2026-04-07          1               1  Transition  Transition     True
# 9  2026-04-14          2               2      Normal      Normal     True
# 10 2026-04-21          2               2      Normal      Normal     True
# 11 2026-04-28          2               2      Normal      Normal     True
# ...

# %% [markdown]
# #### GNN training-loss result
#
# **中文說明：本節訓練純 PyTorch GCN，測試網路拓樸是否足以重建 HMM 狀態標籤。**

# %%
losses = list(getattr(gnn_result, "losses", []))

if losses:
    loss_df = pd.DataFrame({
        "epoch": np.arange(1, len(losses) + 1),
        "loss": losses,
    })
    display(loss_df.tail())

    try:
        from pyecharts.charts import Line
        from pyecharts import options as opts

        loss_line = (
            Line(init_opts=opts.InitOpts(width="100%", height="420px"))
            .add_xaxis(loss_df["epoch"].tolist())
            .add_yaxis(
                "class-weighted cross-entropy",
                loss_df["loss"].round(8).tolist(),
                is_symbol_show=False,
                label_opts=opts.LabelOpts(is_show=False),
            )
            .set_global_opts(
                title_opts=opts.TitleOpts(title="GCN training loss"),
                tooltip_opts=opts.TooltipOpts(trigger="axis"),
                datazoom_opts=[opts.DataZoomOpts(type_="inside")],
            )
        )
        loss_line.render_notebook()
    except ImportError:
        print("Install pyecharts to render the interactive loss chart.")
else:
    print("No loss history was returned.")
# Out:
#      epoch      loss
# 145    146  0.349503
# 146    147  0.347788
# 147    148  0.346079
# 148    149  0.344263
# 149    150  0.342293

# %% [markdown]
# #### HMM versus GNN result summary
#
# **中文說明：本節以 Gaussian HMM 將滾動圖特徵壓縮為市場狀態，並檢查狀態機率、轉移與預測。**

# %%
model_summary = pd.DataFrame([
    {
        "model": "Gaussian HMM",
        "role": "Unsupervised regime discovery",
        "observations": len(hmm_result.states),
        "current_state": current_state,
        "current_regime": current_name,
        "switch_rate": switch_rate(hmm_result.states),
    },
    {
        "model": "Pure-PyTorch GCN",
        "role": "Supervised graph-level reproduction of HMM labels",
        "observations": len(aligned_graphs),
        "current_state": (
            int(predictions[-1])
            if len(predictions) else np.nan
        ),
        "current_regime": (
            regime_names.get(int(predictions[-1]), "Unknown")
            if len(predictions) else "Unavailable"
        ),
        "switch_rate": np.nan,
    },
])

display(model_summary)
# Out:
#               model                                               role  \
# 0      Gaussian HMM                      Unsupervised regime discovery
# 1  Pure-PyTorch GCN  Supervised graph-level reproduction of HMM labels
#
#    observations  current_state current_regime  switch_rate
# 0            80              1     Transition     0.189873
# 1            80              2         Normal          NaN

# %%
plt.figure(figsize=(9, 4))
plt.plot(gnn_result.losses)
plt.xlabel("Epoch")
plt.ylabel("Class-weighted cross-entropy")
plt.title("GCN training loss")
plt.show()

# %% [markdown]
# ## 10. Visualization outputs and conclusions / 視覺化輸出與結論
#
# ### Regime feature history / 狀態特徵歷史
# - **Output:** rolling average curvature, negative-edge ratio, edge stability, and capital concentration.
# - **輸出：**滾動平均曲率、負曲率邊比例、邊穩定度與資金集中度。
# - **Conclusion:** simultaneous falling curvature and rising negative-edge ratio indicate increasing structural fragility.
# - **結論：**若平均曲率下降且負曲率邊比例上升，代表市場網路脆弱性增強。
#
# ### 2D network / 二維網路
# - **Output:** node color = sector, node size = capital share, edge width = absolute correlation, edge color = curvature sign.
# - **輸出：**節點顏色＝產業、大小＝資金占比、邊寬＝相關絕對值、邊色＝曲率正負。
# - **Conclusion:** large nodes joined by thick negative-curvature edges are priority stress links.
# - **結論：**大型節點之間若由粗且負曲率的邊連接，應列為優先壓力觀察對象。
#
# ### Edge-curvature bar and table / 邊曲率長條圖與表格
# - **Output:** correlation, distance, graph weight, curvature, and Ollivier Wasserstein distance.
# - **輸出：**相關係數、距離、圖權重、曲率，以及 Ollivier 的 Wasserstein 距離。
# - **Conclusion:** inspect the lowest-curvature edges first; they are the least locally redundant.
# - **結論：**先檢查曲率最低的邊，因為其局部替代路徑通常最少。
#
# ### Sector momentum and flow heatmap / 產業動能與流量熱圖
# - **Output:** average sector return momentum and a dimensionless model-derived inter-sector flow score.
# - **輸出：**產業平均報酬動能與無量綱的模型產業間流量分數。
# - **Conclusion:** positive momentum plus increasing inflow is stronger confirmation than either signal alone.
# - **結論：**正動能加上流入增強，比單獨任一訊號更具確認力。
#
# ### Capital-flow animation / 資金流動畫
# - **Output:** frame-by-frame evolution; color change represents cell-level increase or decrease from the previous frame.
# - **輸出：**逐幀演化；顏色變化代表相對前一幀的單格增減。
# - **Conclusion:** persistent directional changes matter more than one-frame spikes.
# - **結論：**持續性的方向變化比單幀尖峰更重要。
#
# ### Graph surgery / 圖手術
# - **Output:** before/after stress-test graphs after removing selected negative-curvature edges.
# - **輸出：**移除特定負曲率邊前後的壓力測試網路。
# - **Conclusion:** this is a sensitivity experiment, not a literal prediction that links vanish.
# - **結論：**這是敏感度實驗，不是預測真實市場連結會消失。
#
# ### 3D Ricci Galaxy / 三維 Ricci Galaxy
# - **Output:** sector direction, capital-share radius, and node-curvature height.
# - **輸出：**產業方向、資金占比半徑、節點曲率高度。
# - **Conclusion:** sector clusters and curvature outliers reveal structural grouping and exceptions.
# - **結論：**產業群聚與曲率離群點可揭示結構分組與異常。
#
# ### HMM and GCN / HMM 與 GCN
# - **Output:** HMM regime labels, posterior confidence, transition forecast, GCN accuracy, balanced accuracy, and loss.
# - **輸出：**HMM 狀態、後驗信心、轉移預測、GCN 準確率、平衡準確率與損失。
# - **Conclusion:** GCN performance above the majority baseline suggests graph topology contains useful regime information; it does not independently prove tradable predictability.
# - **結論：**若 GCN 高於多數類別基準，表示圖拓樸含有狀態資訊，但不能單獨證明可交易預測能力。
#
# **中文說明：本節使用計算快速的 Forman-Ricci 建立滾動網路，適合先驗證大量時間幀。**

# %% [markdown]
# ### 11 Export Results
#
# **中文說明：本節匯出特徵、狀態與模型結果，作為可重現分析與後續檢查的資料。**

# %%
OUTPUT = Path("v15_complete_lecture_outputs")
OUTPUT.mkdir(exist_ok=True)

feature_df.to_csv(
    OUTPUT / "rolling_ricci_features.csv",
    index=False,
)
valid_feature_df.to_csv(
    OUTPUT / "hmm_regimes.csv",
    index=False,
)
forecast_df.to_csv(
    OUTPUT / "hmm_five_day_forecast.csv",
    index=False,
)
edge_table.to_csv(
    OUTPUT / "latest_edge_curvature.csv",
    index=False,
)
node_table.to_csv(
    OUTPUT / "latest_node_metrics.csv",
    index=False,
)
momentum.rename("five_day_momentum").to_csv(
    OUTPUT / "sector_momentum.csv",
)
flow.to_csv(
    OUTPUT / "sector_flow_matrix.csv",
)
surgery_summary.to_csv(
    OUTPUT / "surgery_summary.csv",
    index=False,
)
comparison.to_csv(
    OUTPUT / "gnn_hmm_comparison.csv",
    index=False,
)

dataset = {
    "frames": frames,
    "feature_df": feature_df,
    "hmm_states": hmm_result.states,
    "hmm_posterior": hmm_result.posterior,
    "regime_names": regime_names,
    "tickers": TICKERS,
    "parameters": {
        "window": WINDOW,
        "step": STEP,
        "max_frames": MAX_FRAMES,
        "curvature_engine": CURVATURE_ENGINE,
        "ollivier_alpha": OLLIVIER_ALPHA,
        "capital_alpha": CAPITAL_ALPHA,
    },
}

with open(OUTPUT / "v15_complete_dataset.pkl", "wb") as handle:
    pickle.dump(dataset, handle)

print("Exported to:", OUTPUT.resolve())
for path in sorted(OUTPUT.iterdir()):
    print(f"{path.name:36s} {path.stat().st_size:>10,d} bytes")

# %% [markdown]
# ## 12. Final interpretation / 最終解讀
#
# **English conclusion.** Correlation answers *who moves together*. Forman-Ricci quickly screens *which connections are structurally overloaded*. Ollivier-Ricci gives a richer but slower answer about *how similar the two local neighborhoods are*. Use Forman for broad rolling scans and Ollivier for selected frames or suspicious edges. Treat HMM as regime compression, GCN as a topology-information test, and every flow value as a model score rather than a dollar amount.
#
# **中文結論。** 相關係數回答「誰一起漲跌」；Forman-Ricci 快速篩選「哪些連結在結構上較過載」；Ollivier-Ricci 則以較慢但更豐富的方式回答「兩端局部分布有多相似」。大量滾動掃描宜先用 Forman，重點幀或可疑邊再用 Ollivier。HMM 用於壓縮市場狀態，GCN 用於檢驗拓樸是否含狀態資訊；所有資金流數值均應視為模型分數，而非美元金額。

# %% [markdown]
# ## Environment note
#
# The final V15 stack should include:
#
# ```text
# numpy
# pandas
# scipy
# networkx
# yfinance
# scikit-learn
# hmmlearn
# torch
# plotly
# pyecharts
# jupyter
# ```
#
# Do not install or import:
#
# ```text
# tensorflow
# keras
# POT / ot
# GraphRicciCurvature
# torch_geometric
# torch_scatter
# torch_sparse
# ```
#
# **中文說明：本節以 Gaussian HMM 將滾動圖特徵壓縮為市場狀態，並檢查狀態機率、轉移與預測。**
